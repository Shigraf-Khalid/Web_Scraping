# %% [markdown]
# <a href="https://colab.research.google.com/github/Shigraf-Khalid/Web_Scraping/blob/main/Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install beautifulsoup4
! pip install requests

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:

    page=requests.get('https://www.cricbuzz.com/')

except Exception as e:
    error_type, error_obj, error_info = sys.exc_info()
    print ('ERROR FOR LINK:',url)
    print (error_type, 'Line:', error_info.tb_lineno)

time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<div class="cb-nws-intr">Nitish Reddy, Abhishek Sharma and Harshit Rana are among those who secured their maiden contracts </div>,
#  <div class="cb-nws-intr">The 17-year-old scored a brisk 32 on IPL debut for CSK, showing poise, fearlessness and a glimpse of Mumbai's famed batting genes</div>,
#  <div class="cb-nws-intr">Patel notched up his maiden T20I ton as USA won by 149 runs</div>,
#  <div class="cb-nws-intr">With fuller, straighter deliveries at the death, fast bowlers have reclaimed lost ground against the big hitters</div>,
#  <div class="cb-nws-intr">The defending champions will have to pull themselves up from their shocking loss in the previous game where they failed to chase down 112</div>,
#  <div class="cb-nws-intr">Comfortably well-placed at one point, Royals choked again for the second time in a row to lose by two runs</div>,
#  <div class="cb-nws-intr">The lanky fast-bowler has 14 scalps to his name uses his height to the fullest </div>,
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# Nitish Reddy, Abhishek Sharma and Harshit Rana are among those who secured their maiden contracts
#
#
# The 17-year-old scored a brisk 32 on IPL debut for CSK, showing poise, fearlessness and a glimpse of Mumbai's famed batting genes
#
#
# Patel notched up his maiden T20I ton as USA won by 149 runs
#
#
# With fuller, straighter deliveries at the death, fast bowlers have reclaimed lost ground against the big hitters
#
#
# The defending champions will have to pull themselves up from their shocking loss in the previous game where they failed to chase down 112
#
#
# Comfortably well-placed at one point, Royals choked again for the second time in a row to lose by two runs
#
#
# The lanky fast-bowler has 14 scalps to his name uses his height to the fullest
#
#
# The former Indian assistant coach has rejoined the franchise after BCCI's did not renew his contract
#
#
# The inaugural season, featuring both men's and women's competitions, is scheduled to start in July.
#
#
# ...
